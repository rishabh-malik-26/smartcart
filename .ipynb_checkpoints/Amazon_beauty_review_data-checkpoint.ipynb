# %%
import pandas as pd 
import numpy as np
import json
import os
import json
import warnings
warnings.filterwarnings('ignore')
import gzip
import faiss

# %%
reviews = []

with open(r"C:\Users\Rishabh\Downloads\Amazon_Project_Data\Beauty\All_Beauty.jsonl.gz", "rt", encoding="utf-8") as fp:
    for line in fp:
        data_line = json.loads(line.strip())
        reviews.append(data_line)

# %%
df1 = pd.DataFrame(reviews)

# %%
df1.head()
# Out:
#    rating                                      title  \
# 0     5.0  Such a lovely scent but not overpowering.
# 1     4.0     Works great but smells a little weird.
# 2     5.0                                       Yes!
# 3     1.0                          Synthetic feeling
# 4     5.0                                         A+
#
#                                                 text images        asin  \
# 0  This spray is really nice. It smells really go...     []  B00YQ6X8EO
# 1  This product does what I need it to do, I just...     []  B081TJ8YS3
# 2                          Smells good, feels great!     []  B07PNNCSP9
# 3                                     Felt synthetic     []  B09JS339BZ
# 4                                            Love it     []  B08BZ63GMJ
#
#   parent_asin                       user_id      timestamp  helpful_vote  \
# 0  B00YQ6X8EO  AGKHLEW2SOWHNMFQIJGBECAF7INQ  1588687728923             0
# 1  B081TJ8YS3  AGKHLEW2SOWHNMFQIJGBECAF7INQ  1588615855070             1
# 2  B097R46CSY  AE74DYR3QUGVPZJ3P7RFWBGIX7XQ  1589665266052             2
# 3  B09JS339BZ  AFQLNQNQYFWQZPJQZS6V3NZU4QBQ  1643393630220             0
# 4  B08BZ63GMJ  AFQLNQNQYFWQZPJQZS6V3NZU4QBQ  1609322563534             0
#
#    verified_purchase
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True

# %%
df = df1[['rating','parent_asin','user_id']]

# %%
data = []

with open(r"C:\Users\Rishabh\Downloads\Amazon_Project_Data\Beauty\meta_All_Beauty.jsonl (1).gz", "rt", encoding="utf-8") as fp:
    for line in fp:
        data_line = json.loads(line.strip())
        data.append(data_line)

# %%
df2 = pd.DataFrame(data)

# %%
len(df1['parent_asin'].unique())
# Out:
# 112565

# %%
len(df2['parent_asin'].unique()) , len(df1['parent_asin'].unique())
# Out:
# (112590, 112565)

# %%
new_df =pd.merge(df1,df2, on = 'parent_asin')

# %%
df1.shape,df2.shape
# Out:
# ((701528, 10), (112590, 14))

# %%
new_df = new_df.sample(frac = 0.01)

# %%
r_df = new_df[['parent_asin','user_id','rating']]

# %%
from surprise import SVD, Dataset, Reader
from surprise.model_selection import train_test_split
from surprise import accuracy
 
# Define the format
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(r_df[["user_id", "parent_asin", "rating"]], reader)

# Train-test split
trainset, testset = train_test_split(data, test_size=0.2)

# Train SVD model
model = SVD()
model.fit(trainset)

# Predict and evaluate
predictions = model.test(testset)
print("RMSE:", accuracy.rmse(predictions))
# Out:
# RMSE: 1.4851
# RMSE: 1.4850501883622036

# %%
user_mat = model.pu
item_mat = model.qi

# %%
user_mat = user_mat.astype('float32')
item_mat = item_mat.astype('float32')

# %%
user_mat.shape[0],item_mat.shape
# Out:
# (5596, (4560, 100))

# %%
user_ids = [trainset.to_raw_uid(i) for i in range(user_mat.shape[0])]
item_ids = [trainset.to_raw_iid(j) for j in range(item_mat.shape[0])]

# %%
user_df = pd.DataFrame(user_mat,index=user_ids)

# AHAV7SPS3MCGV23T5JLHTDPS6LPA -0.124612  0.005885  ...  0.062998  0.096227
# AHANUEFBAIOKM6MCT3754JIQISVQ  0.020347 -0.064365  ... -0.028126  0.074606
# AH2B6UGUIL5UYL4UD5CHBYJ7KHXA -0.001788  0.254590  ... -0.125468  0.008898
#
#                                     92        93        94        95  \
# AGIACCCJZ7LFOOHKRYYRPPWBPS5Q -0.087715  0.236685  0.029368 -0.066234
# AH5UQHMZEMCQWU26V6X5NEPJJP4A  0.037711 -0.096526  0.020397  0.068699
# AET5BLEE7HZLWV6QKBSMGGFBQUDA  0.067770  0.002966 -0.048246 -0.015564
# AGZME7ZJW3SXJSA3BSBOZ5FDRGIQ  0.124811 -0.070764 -0.051192 -0.330984
# AEIX2B2BF3EVA4W7DW3PCCRVBWWA -0.092984 -0.008294 -0.048572 -0.024985
# ...                                ...       ...       ...       ...
# AFMYU7CYVUMGEH75YJMX2T43TXCQ -0.011705 -0.035691  0.124208  0.039390
# AE77II4WDO3UZFYFRGVOFQQCKBOQ -0.050099  0.027280  0.027548 -0.129971
# AHAV7SPS3MCGV23T5JLHTDPS6LPA -0.028139  0.083671 -0.093827 -0.052325
# AHANUEFBAIOKM6MCT3754JIQISVQ -0.022909 -0.044574 -0.149675 -0.201715
# AH2B6UGUIL5UYL4UD5CHBYJ7KHXA -0.119214 -0.008574 -0.103727 -0.049694
#
#                                     96        97        98        99
# AGIACCCJZ7LFOOHKRYYRPPWBPS5Q  0.018308  0.051995 -0.036798  0.036851
# AH5UQHMZEMCQWU26V6X5NEPJJP4A  0.105101  0.176610 -0.121422  0.094595
# AET5BLEE7HZLWV6QKBSMGGFBQUDA -0.054130 -0.223920 -0.058551 -0.189255
# AGZME7ZJW3SXJSA3BSBOZ5FDRGIQ -0.068133  0.096122 -0.088391 -0.000238
# AEIX2B2BF3EVA4W7DW3PCCRVBWWA  0.082992  0.184656  0.123433 -0.013422
# ...                                ...       ...       ...       ...
# AFMYU7CYVUMGEH75YJMX2T43TXCQ -0.037158  0.154019 -0.139577  0.167950
# AE77II4WDO3UZFYFRGVOFQQCKBOQ  0.026200  0.056272 -0.107504  0.002681
# AHAV7SPS3MCGV23T5JLHTDPS6LPA  0.091079  0.000839  0.157838 -0.040141
# AHANUEFBAIOKM6MCT3754JIQISVQ -0.078491  0.169586  0.071184 -0.151660
# AH2B6UGUIL5UYL4UD5CHBYJ7KHXA -0.079473  0.092145 -0.105335  0.021199
#
# [5596 rows x 100 columns]

# %%
user= user_df.iloc[400] 
user.shape
# Out:
# (100,)

# %%
user_array = np.array(user).reshape(1,-1)

# %%
d = item_mat.shape[1]

index = faiss.IndexFlatIP(d)  
index.add(item_mat)
k  = item_mat.shape[0]

distances,indices = index.search(user_array, k)

# %%
top_user_ids  = indices[0]

# %%
top_dist  = distances[0]

# %%
#for i in top_user_ids:
 #   print(user_df.index[i])

# %%
top_user_ids[0]
# Out:
# 1772

# %%
dist =list(top_dist)

# %%
sim_ids = [user_df.index[i] for i in top_user_ids]

# %%
user_dist_df = pd.DataFrame(dist,sim_ids,columns=['Distance'])

# %%
len(sim_ids)
# Out:
# 4560

# %%
len(r_df['user_id'].unique())
# Out:
# 6990

# %%
r_df['parent_asin'][r_df['user_id'] == 'AFR2TVY45HMKVZU2IBCR3DB2ESAQ']
# Out:
# Series([], Name: parent_asin, dtype: object)

# %%
mat = {}
for i in sim_ids:
    user_r = dict(zip(r_df['parent_asin'][r_df['user_id'] == i],r_df['rating'][r_df['user_id'] == i]))  
    mat[i] = user_r

# %%
#filter_df = r_df[r_df['user_id'].isin(sim_ids)]

# %%
#mat = (filter_df.groupby('user_id').apply(lambda x: dict(zip( x['parent_asin'] ,x['rating'] )) ).to_dict())

# %%
user_dist_df
# Out:
#                               Distance
# AE473N3C62NCTUFKQ3S5MEG7VV6A  0.395182
# AGE43YVBZBNDKZXAYUH7T4PRVFMA  0.379780
# AFPNS3QJZSTRREDG6AWQPZWA76VA  0.373747
# AF62SIYNIKEFQXTYADQ5NWDNUYLQ  0.369976
# AFIS2P42MZBJ2KB6KO655YSZKELA  0.365041
# ...                                ...
# AGRH7ORHR745X5TSZDEO4RRU3HFQ -0.352158
# AGNN2ZWUN2WIUDVC3VCVRE6POMRA -0.357317
# AFFJEOWFZ6HHUIAYUJEKI4ANDLZQ -0.364813
# AHSO6LYXYFBTBYNY4V7R5LSED75Q -0.368823
# AENEHO4ZDUMMLNR5CIBZKZZXNKRA -0.385045
#
# [4560 rows x 1 columns]

# %%
df_mat =pd.DataFrame(mat)

# %%
df_mat.head()
# Out:
#             AE473N3C62NCTUFKQ3S5MEG7VV6A  AGE43YVBZBNDKZXAYUH7T4PRVFMA  \
# B01M1OFZOG                           5.0                           NaN
# B07DM82YBT                           NaN                           5.0
# B00JQI7JBK                           NaN                           NaN
# B010B5ZE4U                           NaN                           NaN
# B07STXMKKT                           NaN                           NaN
#
#             AFPNS3QJZSTRREDG6AWQPZWA76VA  AF62SIYNIKEFQXTYADQ5NWDNUYLQ  \
# B01M1OFZOG                           NaN                           NaN
# B07DM82YBT                           NaN                           NaN
# B00JQI7JBK                           5.0                           NaN
# B010B5ZE4U                           NaN                           5.0
# B07STXMKKT                           NaN                           NaN
#
#             AFIS2P42MZBJ2KB6KO655YSZKELA  AHUGKUVWBYGBSXW3SSMMR2QNTKNQ  \
# B01M1OFZOG                           NaN                           NaN
# B07DM82YBT                           NaN                           NaN
# B00JQI7JBK                           NaN                           NaN
# B010B5ZE4U                           NaN                           NaN
# B07STXMKKT                           5.0                           NaN
#
#             AFO456XNS5YAY3LHNVPLRJUJDCWA  AEBAUHHD6BLR276NRQL4IQZK7AIA  \
# B01M1OFZOG                           NaN                           NaN
# B07DM82YBT                           NaN                           NaN
# B00JQI7JBK                           NaN                           NaN
# B010B5ZE4U                           NaN                           NaN
# B07STXMKKT                           NaN                           NaN
#
#             AGHABE2FIHA2R6QH6ZRXB2WOEJCA  AGHL4YKLZXMA6EJVQ3HMA7R7TAEQ  ...  \
# B01M1OFZOG                           NaN                           NaN  ...
# B07DM82YBT                           NaN                           NaN  ...
# B00JQI7JBK                           NaN                           NaN  ...
# B010B5ZE4U                           NaN                           NaN  ...
# B07STXMKKT                           NaN                           NaN  ...
#
#             AHKTCQ5JJQOYHGAHBPKINIRVKUHQ  AHHRZK4U2MTWGIRT2M3U3SPQ6SZA  \
# B01M1OFZOG                           NaN                           NaN
# B07DM82YBT                           NaN                           NaN
# B00JQI7JBK                           NaN                           NaN
# B010B5ZE4U                           NaN                           NaN
# B07STXMKKT                           NaN                           NaN
#
#             AER62CDQFLZ5HUQPV5PELHQBWCUQ  AEKJYOIX4FMCCFGQ7SKXDVIPPJDQ  \
# B01M1OFZOG                           NaN                           NaN
# B07DM82YBT                           NaN                           NaN
# B00JQI7JBK                           NaN                           NaN
# B010B5ZE4U                           NaN                           NaN
# B07STXMKKT                           NaN                           NaN
#
#             AH2MORTGCST5G33AMEITA47QDK6Q  AGRH7ORHR745X5TSZDEO4RRU3HFQ  \
# B01M1OFZOG                           NaN                           NaN
# B07DM82YBT                           NaN                           NaN
# B00JQI7JBK                           NaN                           NaN
# B010B5ZE4U                           NaN                           NaN
# B07STXMKKT                           NaN                           NaN
#
#             AGNN2ZWUN2WIUDVC3VCVRE6POMRA  AFFJEOWFZ6HHUIAYUJEKI4ANDLZQ  \
# B01M1OFZOG                           NaN                           NaN
# B07DM82YBT                           NaN                           NaN
# B00JQI7JBK                           NaN                           NaN
# B010B5ZE4U                           NaN                           NaN
# B07STXMKKT                           NaN                           NaN
#
#             AHSO6LYXYFBTBYNY4V7R5LSED75Q  AENEHO4ZDUMMLNR5CIBZKZZXNKRA
# B01M1OFZOG                           NaN                           NaN
# B07DM82YBT                           NaN                           NaN
# B00JQI7JBK                           NaN                           NaN
# B010B5ZE4U                           NaN                           NaN
# B07STXMKKT                           NaN                           NaN
#
# [5 rows x 4560 columns]

# %%
t_df = df_mat.fillna(0)

# %%
t_df
# Out:
#             AE473N3C62NCTUFKQ3S5MEG7VV6A  AGE43YVBZBNDKZXAYUH7T4PRVFMA  \
# B01M1OFZOG                           5.0                           0.0
# B07DM82YBT                           0.0                           5.0
# B00JQI7JBK                           0.0                           0.0
# B010B5ZE4U                           0.0                           0.0
# B07STXMKKT                           0.0                           0.0
# ...                                  ...                           ...
# B01M0DFPV1                           0.0                           0.0
# B002D4IBFM                           0.0                           0.0
# B07YSFYJSH                           0.0                           0.0
# B079TJVNLL                           0.0                           0.0
# B00T9NSPH4                           0.0                           0.0
#
#             AFPNS3QJZSTRREDG6AWQPZWA76VA  AF62SIYNIKEFQXTYADQ5NWDNUYLQ  \
# B01M1OFZOG                           0.0                           0.0
# B07DM82YBT                           0.0                           0.0
# B00JQI7JBK                           5.0                           0.0
# B010B5ZE4U                           0.0                           5.0
# B07STXMKKT                           0.0                           0.0
# ...                                  ...                           ...
# B01M0DFPV1                           0.0                           0.0
# B002D4IBFM                           0.0                           0.0
# B07YSFYJSH                           0.0                           0.0
# B079TJVNLL                           0.0                           0.0
# B00T9NSPH4                           0.0                           0.0
#
#             AFIS2P42MZBJ2KB6KO655YSZKELA  AHUGKUVWBYGBSXW3SSMMR2QNTKNQ  \
# B01M1OFZOG                           0.0                           0.0
# B002D4IBFM                           5.0                           0.0
# B07YSFYJSH                           0.0                           0.0
# B079TJVNLL                           0.0                           0.0
# B00T9NSPH4                           0.0                           0.0
#
#             AGNN2ZWUN2WIUDVC3VCVRE6POMRA  AFFJEOWFZ6HHUIAYUJEKI4ANDLZQ  \
# B01M1OFZOG                           0.0                           0.0
# B07DM82YBT                           0.0                           0.0
# B00JQI7JBK                           0.0                           0.0
# B010B5ZE4U                           0.0                           0.0
# B07STXMKKT                           0.0                           0.0
# ...                                  ...                           ...
# B01M0DFPV1                           0.0                           0.0
# B002D4IBFM                           0.0                           0.0
# B07YSFYJSH                           0.0                           5.0
# B079TJVNLL                           0.0                           0.0
# B00T9NSPH4                           0.0                           0.0
#
#             AHSO6LYXYFBTBYNY4V7R5LSED75Q  AENEHO4ZDUMMLNR5CIBZKZZXNKRA
# B01M1OFZOG                           0.0                           0.0
# B07DM82YBT                           0.0                           0.0
# B00JQI7JBK                           0.0                           0.0
# B010B5ZE4U                           0.0                           0.0
# B07STXMKKT                           0.0                           0.0
# ...                                  ...                           ...
# B01M0DFPV1                           0.0                           0.0
# B002D4IBFM                           0.0                           0.0
# B07YSFYJSH                           0.0                           0.0
# B079TJVNLL                           5.0                           0.0
# B00T9NSPH4                           0.0                           5.0
#
# [3816 rows x 4560 columns]

# %%
product_scores = np.dot(user_dist_df.T,t_df.T)
product_scores

# %%
## Similar user ids
for i in top_user_ids:
    print(user_df.index[i])

# %%
user_rating = r_df['rating'][r_df['user_id'] == 'AFER7OPRGQOYGVSQCMVCPFLY4PKA']

# %%
sim_products = [r_df['parent_asin'][r_df['user_id'] == i] for i in sim_ids]

# %%
distance_df = pd.DataFrame(distances[0],columns=['Distance'])

# %%
indice_df = pd.DataFrame(indices[0],columns = ['Index'])

# %%
score_ind = pd.concat([distance_df,indice_df],axis = 1)

# %%
score_ind
# Out:
#       Distance  Index
# 0     0.395182   1772
# 1     0.379780   2827
# 2     0.373747   2957
# 3     0.369976     59
# 4     0.365041    517
# ...        ...    ...
# 4555 -0.352158   1971
# 4556 -0.357317   2712
# 4557 -0.364813   4078
# 4558 -0.368823   1272
# 4559 -0.385045   3594
#
# [4560 rows x 2 columns]

# %%
item_df.index[6424]

# %%
print(new_df['images_y'].iloc[2154][0]['large'])
print(new_df['images_y'].iloc[1037][0]['large'])
print(new_df['images_y'].iloc[6424][0]['large'])
print(new_df['images_y'].iloc[7250][0]['large'])
print(new_df['images_y'].iloc[252][0]['large'])

# %%
print(new_df['title_y'].iloc[2154] )
print(new_df['title_y'].iloc[1037])
print(new_df['title_y'].iloc[6424])
print(new_df['title_y'].iloc[7250])
print(new_df['title_y'].iloc[252])

# %%
#!pip install pyspark

# %%
#from pyspark.sql import SparkSession

# %%
#spark = SparkSession.builder.appName("MyFirstSparkApp").getOrCreate()

# %%
#import os
#print("JAVA_HOME:", os.environ.get("JAVA_HOME"))

# %%
#user_df = pd.DataFrame(user_mat)

# %%
#item_df = pd.DataFrame(item_mat)

# %%
#df_spark = spark.createDataFrame(item_df)

# %%
#spark_user_df = spark.createDataFrame(user_mat)
